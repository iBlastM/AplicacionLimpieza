# %%
import geopandas as gpd

path_geojson = r'D:\Metrix\BaseProgramasSociales\SECCION_ELECT_SABANA_2024.geojson'
gdf = gpd.read_file(path_geojson, usecols=['SECCION', 'geometry'])
# Out:
# d:\Metrix\.venv\Lib\site-packages\pyogrio\raw.py:200: RuntimeWarning: driver GeoJSON does not support open option USECOLS
#   return ogr_read(

# %%
gdf.columns
# Out:
# Index(['fid', 'CVE_PAIS', 'NOM_PAIS', 'CVE_ENT', 'NOM_ENT', 'CVE_MUN',
#        'CU_MUN', 'NOM_MUN', 'DISTRITO_F', 'DISTRITO_L', 'SECCION',
#        'CIRCUNSCRI', 'APOYOS_25', 'SE24_#', 'SE24_MUNICIPIO', 'SE24_ZONA',
#        'SE24_LISTA NOMINAL', 'SE24_VOTOS EMITIDOS', 'SE24_PARTICIPACION',
#        'SE24_ABSTENCION %', 'SE24_1ER LUGAR', 'SE24_VOTOS', 'SE24_VOTANCION %',
#        'SE24_DIFERENCIA', 'SE24_Diferencia\n2do (%)', 'SE24_2do Lugar',
#        'SE24_Votos', 'SE24_Votación (%)', 'SE24_Diferencia\n3ero (Votos)',
#        'SE24_Diferencia\n3ero (%)', 'SE24_3er Lugar', 'SE24_Votos_1',
#        'SE24_Votación (%)_1', 'SE24_1PP_MV', 'SE24_Votos_2',
#        'SE24_Votación (%)_2', 'SE24_2PP_MV', 'SE24_Votos_3',
#        'SE24_Votación (%)_3', 'SE24_3PP_MV', 'SE24_Votos_4',
#        'SE24_Votación (%)_4', 'SE24_PAN', 'SE24_Votación (%)_5', 'SE24_PRI',
#        'SE24_Votación (%)_6', 'SE24_PRD', 'SE24_Votación (%)_7',
# ...

# %%
print(gdf['SECCION'].value_counts())
# Out:
# SECCION
# 35     1
# 36     1
# 37     1
# 38     1
# 39     1
#       ..
# 902    1
# 903    1
# 918    1
# 919    1
# 920    1
# Name: count, Length: 953, dtype: int64
