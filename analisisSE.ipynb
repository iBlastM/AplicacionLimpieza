# %%
import geopandas as gpd

path_geojson = r'D:\Metrix\BaseProgramasSociales\base_limpia.geojson'
gdf = gpd.read_file(path_geojson, usecols=['SECCION', 'geometry'])
# Out:
# d:\Metrix\.venv\Lib\site-packages\pyogrio\raw.py:200: RuntimeWarning: driver GeoJSON does not support open option USECOLS
#   return ogr_read(

# %%
gdf.columns
# Out:
# Index(['ID_USUARIO', 'ID_PERSONA', 'NOMBRE(S)_DE_PILA', 'AP_PATERNO',
#        'AP_MATERNO', 'CURP', 'GENERO', 'FECHA_NACIMIENTO', 'CALLE', 'NUM_EXT',
#        'NUM_INT', 'COLONIA', 'CODIGO_POSTAL', 'NOMBRE_PROGRAMA',
#        'FECHA_REGISTRO', 'DESCRIPCION', 'CELULAR', 'TELEFONO', 'CORREO',
#        'ID_PARENTESCO', 'NOMBRE_PRE', 'NOMBRE_COMPLETO', 'ESTADO', 'MUNICIPIO',
#        'ANO_PROGRAMA', 'DIRECCION_HOMOLOGADA', 'LATITUD', 'LONGITUD',
#        'SECCION_ELECTORAL', 'DISTRITO_F', 'DISTRITO_L', 'geometry'],
#       dtype='object')

# %%
print(gdf['LATITUD'].value_counts())
# Out:
# LATITUD
# 20.515889    4
# 20.517181    4
# 20.417582    3
# 20.512560    2
# 20.486540    2
#             ..
# 20.515423    1
# 20.523232    1
# 20.533892    1
# 20.533236    1
# 20.484192    1
# Name: count, Length: 82, dtype: int64
